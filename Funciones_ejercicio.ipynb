# %% [markdown]
# <a href="https://colab.research.google.com/github/gemolinausistemas-ai/psychic-tribble-funciones-/blob/main/Funciones_ejercicio.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import DAV as gab
gab.sumar(1,3)
# Out:
# 4

# %%
import NO as gab
gab.celsius_a_fahrenheit(40)
# Out:
# 104.0

# %%
import NO as gab
gab.area_circulo(3)
# Out:
# 28.274333882308138

# %%
import NO as gab
gab.cuadrado(3)
# Out:
# 9

# %%
import DAV as gab
gab.signo_numero(5)
# Out:
# 'positivo'

# %%
import DAV as gab
gab.contar_vocales("hpola")
# Out:
# 2

# %%
import DAV as gab
gab.tabla_multiplicar(6)
# Out:
# Tabla de multiplicar del 6:
# 6 x 1 = 6
# 6 x 2 = 12
# 6 x 3 = 18
# 6 x 4 = 24
# 6 x 5 = 30
# 6 x 6 = 36
# 6 x 7 = 42
# 6 x 8 = 48
# 6 x 9 = 54
# 6 x 10 = 60

# %%
import DAV as gab
gab.saludar("hola")
# Out:
# '¡Hola, hola! Bienvenido/a.'

# %%
import DAV as gab
gab.es_par_o_impar(2)
# Out:
# 'par'

# %%
import DAV as gab
gab.area_triangulo(2,3)
# Out:
# 3.0

# %%
import DAV as gab
gab.menu_areas()
# Out:
# --- MENÚ DE CÁLCULO DE ÁREAS ---
# 1. Área de un círculo
# 2. Área de un triángulo
# 3. Área de un rectángulo
# 4. Salir
